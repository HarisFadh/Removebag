# %% [markdown]
# # Gambar asli

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cv2

# %%
citra = imread(fname="tangan.jpg")
spek = imread(fname="spek_tangan.jpg")


print("dimensi citra :",citra.shape)
print("dimensi keterangan :",spek.shape)

fig,axes = plt.subplots(1,2,figsize=(15,11))
ax = axes.ravel()

ax[0].imshow(citra)
ax[0].set_title("Citra")
ax[1].imshow(spek)
ax[1].set_title("Spek")
# Out:
# dimensi citra : (1156, 534, 3)
# dimensi keterangan : (1600, 738, 3)
# Text(0.5, 1.0, 'Spek')

# %% [markdown]
# # Menghilangkan Background

# %%
from rembg import remove
from PIL import Image

# %%
input_path = 'tangan.jpg'
output_path = 'Hasil.png'
input = Image.open(input_path)
output = remove(input)

plt.imshow(output)

# %%
output.save(output_path)
